# %%
from tensorflow.keras.models import model_from_json
import numpy as np
from tensorflow.keras.preprocessing import image
#import keras.preprocessing.image
#from tensorflow.keras.utils import load_img, img_to_array

json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights("model1.h5")
print("Loaded model from disk")

def classify(img_file):
    img_name = img_file
    test_image = image.load_img(img_name, target_size = (64, 64))

    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis=0)
    result = model.predict(test_image)

    if result[0][0] == 1:
        prediction = 'Cat'
    else:
        prediction = 'Dog'
    print(prediction,img_name)


import os
path = 'C:\\Users\\kaush\\OneDrive\\Desktop\\INTERNSHIP\\proj222\\Dataset\\test'
files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
   for file in f:
     if '.jpg' in file:
       files.append(os.path.join(r, file))

for f in files:
   classify(f)
   print('\n')
# Out:
# Loaded model from disk
# 1/1 [==============================] - 0s 109ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\336.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\337.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\338.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\339.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\340.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\341.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\342.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\343.jpg
#
#
# 1/1 [==============================] - 0s 31ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\344.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\345.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\346.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\347.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\348.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\349.jpg
#
#
# 1/1 [==============================] - 0s 31ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\350.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\351.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\352.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\353.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\354.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\355.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\356.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\357.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\358.jpg
#
#
# 1/1 [==============================] - 0s 31ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\359.jpg
#
#
# 1/1 [==============================] - 0s 31ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\360.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\361.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\362.jpg
#
#
# 1/1 [==============================] - 0s 31ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\363.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\364.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\365.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\366.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\367.jpg
#
#
# 1/1 [==============================] - 0s 31ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\368.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\369.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\370.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\371.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\372.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\373.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\374.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\375.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\376.jpg
#
#
# 1/1 [==============================] - 0s 16ms/step
# Cat C:\Users\kaush\OneDrive\Desktop\INTERNSHIP\proj222\Dataset\test\377.jpg
